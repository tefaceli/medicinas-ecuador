# %% [markdown]
# # Procesos adjudicados
# This notebook will include the analysis of all the processes that got a concract. It has a scraper for getting extra information on each process, then uses merging for having other extra data about the medicine, and then includes the analysis.
#
# Each row in this analysis (414) is one item: one specific combination of a medicine, in a form, concentration and comercial presentation.

# %% [markdown]
# ## 1. Scraper - details of each contract
# Firstly, to have more info on each contract, we have a scraper for getting the info on quantity, item budget and complete budget.

# %%
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import pandas as pd
import asyncio

# %%
df = pd.read_csv("adjudicados.csv")

# %%
df.head(1)
# Out:
#           codigo                                        detalle_url  \
# 0  SICM-500-2022  https://modulocomprascorporativas.compraspubli...
#
#                                                 item  \
# 0  DCI: LIDOCAÍNA SIN EPINEFRINA - FORMA FARMACÉU...
#
#            principio_activo                  forma_farmaceutica concentracion  \
# 0  lidocaína sin epinefrina  sólido cutáneo parche transdérmico           5 %
#
#   presentacion_comercial                       estado  presupuesto  provincia  \
# 0  caja x parche/parches  Adjudicado oferente ganador          5.0  pichincha
#
#   canton    fecha_publicacion       descripcion
# 0  quito  2022-06-23 08:00:00  sistema nervioso

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=True)
page = await browser.new_page()

data = []

for i, row in df.head(5).iterrows():
    url = row["detalle_url"]
    item = {}
    item["codigo"] = row["codigo"]
    
    await asyncio.sleep(1)
    print(f"\rProcessing index: {i}, {url}", end="")
    try:
        max_attempts = 2
        for attempt in range(max_attempts):
            await page.goto(url, timeout=10000)
            await asyncio.sleep(3)
        
        try:
            await page.locator("a:has-text('Ver Resultados')").click()
            await asyncio.sleep(3)
        except:
            print(f"There is no 'Ver Resultados' in {url}")
            
        html = await page.content()
        soup = BeautifulSoup(html, "lxml")
        
        table = soup.select_one("table#rounded-corner tbody")
        row = table.find_all("td")
        if len(row) < 8:
            print(f"----- Incomplete row on {url}")
            continue
    
        item["cum_id"] = row[0].get_text(strip=True)
        item["cantidad"] = row[5].get_text(strip=True)
        item["precio_referencial"] = row[6].get_text(strip=True)
        item["subtotal"] = row[7].get_text(strip=True)


        adju_table = soup.select_one("table#tableadjudicacion")
        adju_rows = adju_table.find_all("tr")
        try:
            item["proveedor_adjudicado"] = adju_rows[0].find_all("td")[1].get_text(strip=True)
            item["valor_adjudicado"] = adju_rows[1].find_all("td")[1].get_text(strip=True)
            item["fecha_adjudicacion"] = adju_rows[3].find_all("td")[1].get_text(strip=True)
        except:
            continue
        
        data.append(item)    
        
    except:
        print(f"ERROR processing {url}")
        continue
# Out:
# Processing index: 4, https://modulocomprascorporativas.compraspublicas.gob.ec/ProcesoContratacion/compras/PC/informacionProcesoContratacion2.cpe?idSoliCompra=sGLIxWT-5eloFFbtFRuKxNWXmfGIylrO6hEaZXo80nk,

# %%
len(data)
# Out:
# 5

# %%
details = pd.json_normalize(data)

# %%
details.head()
# Out:
#           codigo           cum_id cantidad precio_referencial  \
# 0  SICM-500-2022  N01BB02SCT220X0   184631       USD 5.000000
# 1  SICM-519-2022  J05AR10SOR149X0    89200       USD 0.270000
# 2  SICM-520-2022  J05AR03SOR189X0   189144       USD 0.438544
# 3  SICM-503-2022  P01CB01LPR194A8    18500       USD 3.797072
# 4  SICM-504-2022  A07EC02SOP061X0   199725       USD 1.308369
#
#              subtotal                       proveedor_adjudicado  \
# 0  USD 923,155.000000            GRUNENTHAL ECUATORIANA CIA LTDA
# 1   USD 24,084.000000  FARMAYALA PHARMACEUTICAL COMPANY S.A. FPC
# 2   USD 82,947.966336                 LABORATORIOS LACFARMA S.A.
# 3   USD 70,245.832000                              OFTALVIS S.A.
# 4  USD 261,313.998525                     NEOETHICALS CIA. LTDA.
#
#   valor_adjudicado   fecha_adjudicacion
# 0     USD 2.990000  2022-09-05 13:11:06
# 1     USD 0.264626  2022-12-21 13:25:27
# 2     USD 0.327000  2022-12-08 16:42:39
# 3     USD 3.560000  2022-09-05 16:36:02
# 4     USD 0.850000  2022-09-21 13:16:40

# %%
details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   codigo                5 non-null      object
#  1   cum_id                5 non-null      object
#  2   cantidad              5 non-null      object
#  3   precio_referencial    5 non-null      object
#  4   subtotal              5 non-null      object
#  5   proveedor_adjudicado  5 non-null      object
#  6   valor_adjudicado      5 non-null      object
#  7   fecha_adjudicacion    5 non-null      object
# dtypes: object(8)
# memory usage: 452.0+ bytes

# %%
#I should clean details first, specially in numbers columns

# %%
df = pd.merge(df, details, on="codigo", how="left")

# %%
df.head(1)
# Out:
#           codigo                                        detalle_url  \
# 0  SICM-500-2022  https://modulocomprascorporativas.compraspubli...
#
#                                               objeto  \
# 0  DCI: LIDOCAÍNA SIN EPINEFRINA - FORMA FARMACÉU...
#
#                    medicina                  forma_farmaceutica concentracion  \
# 0  Lidocaína Sin Epinefrina  Sólido Cutáneo Parche Transdérmico           5 %
#
#   presentacion_comercial                       estado  presupuesto  \
# 0  Caja X Parche/Parches  Adjudicado oferente ganador          5.0
#
#     provincia  canton    fecha_publicacion           cum_id cantidad  \
# 0  Pichincha    Quito  2022-06-23 08:00:00  N01BB02SCT220X0   184631
#
#   precio_referencial            subtotal
# 0       USD 5.000000  USD 923,155.000000

# %%
len(df)
# Out:
# 414

# %%
df.head(1)
# Out:
#              code                                                url  \
# 0  SICM-500-2022   https://modulocomprascorporativas.compraspubli...
#
#                                               objeto  \
# 0  DCI: LIDOCAÍNA SIN EPINEFRINA - FORMA FARMACÉU...
#
#                    medicina                  forma_farmaceutica concentracion  \
# 0  Lidocaína Sin Epinefrina  Sólido Cutáneo Parche Transdérmico           5 %
#
#   presentacion_comercial                       estado   provincia  canton  \
# 0  Caja X Parche/Parches  Adjudicado oferente ganador  Pichincha    Quito
#
#    presupuesto   fecha_publicacion
# 0          5.0  2022-06-23 8:00:00

# %%
summary.columns
# Out:
# Index(['objeto_contractual', 'proveedor', 'cantidad',
#        'monto_total_adjudicado'],
#       dtype='object')

# %%
summary = summary.rename(columns={"cantidad": "sum_cantidad_ordenes", "monto_total_adjudicado": "sum_valor_ordenes"})

# %%
merged = df.merge(summary, left_on="objeto", right_on="objeto_contractual")

# %%
merged = merged.drop("objeto_contractual", axis=1)

# %%
merged.head()
# Out:
#              code                                                url  \
# 0  SICM-500-2022   https://modulocomprascorporativas.compraspubli...
# 1  SICM-519-2022   https://modulocomprascorporativas.compraspubli...
# 2  SICM-520-2022   https://modulocomprascorporativas.compraspubli...
# 3  SICM-503-2022   https://modulocomprascorporativas.compraspubli...
# 4  SICM-504-2022   https://modulocomprascorporativas.compraspubli...
#
#                                               objeto  \
# 0  DCI: LIDOCAÍNA SIN EPINEFRINA - FORMA FARMACÉU...
# 1  DCI: LOPINAVIR + RITONAVIR - FORMA FARMACÉUTIC...
# 2  DCI: TENOFOVIR + EMTRICITABINA - FORMA FARMACÉ...
# 3  DCI: MEGLUMINA ANTIMONIATO - FORMA FARMACÉUTIC...
# 4  DCI: MESALAZINA - FORMA FARMACÉUTICA: SÓLIDO O...
#
#                     medicina                  forma_farmaceutica  \
# 0   Lidocaína Sin Epinefrina  Sólido Cutáneo Parche Transdérmico
# 1      Lopinavir + Ritonavir                         Sólido Oral
# 2  Tenofovir + Emtricitabina                         Sólido Oral
# 3      Meglumina Antimoniato                  Líquido Parenteral
# 4                 Mesalazina                   Sólido Oral Polvo
#
#      concentracion                             presentacion_comercial  \
# 0              5 %                              Caja X Parche/Parches
# 1   200 MG + 50 MG  Caja X Frasco Dosis Personal, No Envase Hospit...
# 2  300 MG + 200 MG                                      Caja X Frasco
# 3        300 MG/ML                            Caja X Ampolla-S X 5 Ml
# 4         1 000 MG                              Caja X Sobres/Sachets
#
#                         estado   provincia  canton  presupuesto  \
# 0  Adjudicado oferente ganador  Pichincha    Quito         5.00
# 1   Adjudicado otros oferentes  Pichincha    Quito         0.27
# 2   Adjudicado otros oferentes  Pichincha    Quito         0.44
# 3  Adjudicado oferente ganador  Pichincha    Quito         3.80
# 4  Adjudicado oferente ganador  Pichincha    Quito         1.31
#
#     fecha_publicacion                                  proveedor  \
# 0  2022-06-23 8:00:00            Grunenthal Ecuatoriana Cia Ltda
# 1  2022-06-23 8:00:00  Farmayala Pharmaceutical Company S.A. Fpc
# 2  2022-06-23 8:00:00                 Laboratorios Lacfarma S.A.
# 3  2022-06-23 8:00:00                              Oftalvis S.A.
# 4  2022-06-23 8:00:00                     Neoethicals Cia. Ltda.
#
#    sum_cantidad_ordenes  sum_valor_ordenes
# 0               1552520          4642043.0
# 1                162360            42964.0
# 2                189750            62048.0
# 3                 10330            36774.0
# 4                120000           102002.0

# %%
#Check if there are processes with no supplier...
merged[merged["proveedor"].isna()]
# Out:
#                 code                                                url  \
# 392  SICM2-561-2022   https://modulocomprascorporativas.compraspubli...
# 393  SICM2-451-2022   https://modulocomprascorporativas.compraspubli...
#
#                                                 objeto     medicina  \
# 392  DCI: RUXOLITINIB - FORMA FARMACÉUTICA: SÓLIDO ...  Ruxolitinib
# 393  DCI: RUXOLITINIB - FORMA FARMACÉUTICA: SÓLIDO ...  Ruxolitinib
#
#     forma_farmaceutica concentracion presentacion_comercial  \
# 392        Sólido Oral          5 MG  Caja X Blíster/Ristra
# 393        Sólido Oral         15 MG  Caja X Blíster/Ristra
#
#                          estado   provincia  canton  presupuesto  \
# 392  Adjudicado otros oferentes  Pichincha    Quito        48.22
# 393  Adjudicado otros oferentes  Pichincha    Quito        81.59
#
#       fecha_publicacion proveedor  sum_cantidad_ordenes  sum_valor_ordenes
# 392  2023-10-06 8:00:00       NaN                  1800            81612.0
# 393  2023-10-06 8:00:00       NaN                  2520           193334.0

# %%
for url in merged[merged["proveedor"].isna()]["url"]:
    print(url)
# Out:
# https://modulocomprascorporativas.compraspublicas.gob.ec/ProcesoContratacion/compras/PC/informacionProcesoContratacion2.cpe?idSoliCompra=nVItkprLhQu0SUhbyW3XXyhHMVCBrBftJPux9Axn24E,
# https://modulocomprascorporativas.compraspublicas.gob.ec/ProcesoContratacion/compras/PC/informacionProcesoContratacion2.cpe?idSoliCompra=XGXGTZFylZFmx2faLBq2BOzllYNRv0c0_ahT_Jb5OjY,
